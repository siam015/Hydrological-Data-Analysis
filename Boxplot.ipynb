# %%
pip install xlrd==1.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 103 kB 5.2 MB/s
# ...
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Lama_203_Dischargedata_Monthly_Boxplot_original.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3621 entries, 0 to 3620
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              3621 non-null   int64
#  1   Month             3621 non-null   object
#  2   Year              3621 non-null   int64
#  3   Day               3621 non-null   int64
#  4   WL(m)             3621 non-null   float64
#  5   Discharge (m3/s)  3621 non-null   float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 169.9+ KB

# %%
discharge = df.loc[:,["Month","Discharge (m3/s)"]]

# %%
discharge
# Out:
#      Month  Discharge (m3/s)
# 0      Jan          4.154046
# 1      Jan          4.154046
# 2      Jan          4.154046
# 3      Jan          4.154046
# 4      Jan          4.154046
# ...    ...               ...
# 3616   Dec          5.153798
# 3617   Dec          5.153798
# 3618   Dec          5.153798
# 3619   Dec          5.063798
# 3620   Dec          5.063798
#
# [3621 rows x 2 columns]

# %%
jan = discharge[discharge["Month"]=="Jan"]
jan_list = discharge['Discharge (m3/s)'].squeeze()

# %%
feb = discharge[discharge["Month"]=="Feb"]
feb_list = discharge['Discharge (m3/s)'].squeeze()

# %%
mar = discharge[discharge["Month"]=="Mar"]
mar_list = discharge['Discharge (m3/s)'].squeeze()

# %%
apr = discharge[discharge["Month"]=="Apr"]
apr_list = discharge['Discharge (m3/s)'].squeeze()

# %%
may = discharge[discharge["Month"]=="May"]
may_list = discharge['Discharge (m3/s)'].squeeze()

# %%
jun = discharge[discharge["Month"]=="Jun"]
jun_list = discharge['Discharge (m3/s)'].squeeze()

# %%
jul = discharge[discharge["Month"]=="Jul"]
jul_list = discharge['Discharge (m3/s)'].squeeze()

# %%
aug = discharge[discharge["Month"]=="Aug"]
aug_list = discharge['Discharge (m3/s)'].squeeze()

# %%
sep = discharge[discharge["Month"]=="Sep"]
sep_list = discharge['Discharge (m3/s)'].squeeze()

# %%
oct = discharge[discharge["Month"]=="Oct"]
oct_list = discharge['Discharge (m3/s)'].squeeze()

# %%
nov = discharge[discharge["Month"]=="Nov"]
nov_list = discharge['Discharge (m3/s)'].squeeze()

# %%
dec = discharge[discharge["Month"]=="Dec"]
dec_list = discharge['Discharge (m3/s)'].squeeze()

# %%
new_discharge = pd.DataFrame({'Jan': jan_list,'Feb': feb_list,'Mar': mar_list,'Apr': apr_list,'May': may_list,'Jun':jun_list,'Jul':jul_list,'Aug': aug_list,'Sep': sep_list,"Oct": oct_list,"Nov":nov_list,"Dec":dec_list})

# %%
new_discharge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3621 entries, 0 to 3620
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     3621 non-null   float64
#  1   Feb     3621 non-null   float64
#  2   Mar     3621 non-null   float64
#  3   Apr     3621 non-null   float64
#  4   May     3621 non-null   float64
#  5   Jun     3621 non-null   float64
#  6   Jul     3621 non-null   float64
#  7   Aug     3621 non-null   float64
#  8   Sep     3621 non-null   float64
#  9   Oct     3621 non-null   float64
#  10  Nov     3621 non-null   float64
#  11  Dec     3621 non-null   float64
# dtypes: float64(12)
# memory usage: 339.6 KB

# %%
new_discharge.boxplot(column = ["Jan"])

# %% [markdown]
# Trial with new data

# %%
df_try = pd.read_csv('wet-bulb-temperature-hourly.csv', 
                 parse_dates = ['wbt_date'], 
                 index_col='wbt_date')
df_try
# Out:
#             wbt_time  wet_bulb_temperature
# wbt_date
# 1982-01-01         1                  24.7
# 1982-01-01         2                  24.5
# 1982-01-01         3                  24.3
# 1982-01-01         4                  24.2
# 1982-01-01         5                  24.2
# ...              ...                   ...
# 2022-07-31        20                  24.8
# 2022-07-31        21                  24.9
# 2022-07-31        22                  25.4
# 2022-07-31        23                  25.5
# 2022-07-31        24                  25.4
#
# [355728 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(12,5))
sns.boxplot(x = df_try.index.month,
                y = df_try['wet_bulb_temperature'], 
                ax = ax)

# %%
discharge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3621 entries, 0 to 3620
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             3621 non-null   object
#  1   Discharge (m3/s)  3621 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 56.7+ KB

# %%
fig, ax = plt.subplots(figsize=(12,5))
sns.boxplot(x = discharge["Month"],
                y = discharge['Discharge (m3/s)'], 
                ax = ax)

plt.savefig("boxplot.jpg")

# %%
discharge.max()
# Out:
# Month                        Sep
# Discharge (m3/s)    65123.044579
# dtype: object

# %%
discharge.describe()
# Out:
#        Discharge (m3/s)
# count       3621.000000
# mean         162.720583
# std         2015.573411
# min            2.460066
# 25%            5.332894
# 50%            7.887603
# 75%           18.734552
# max        65123.044579

# %%
filt = df["Discharge (m3/s)"] >10000

# %%
filtered = df[filt]

# %%
filtered
# Out:
#        Date Month  Year  Day   WL(m)  Discharge (m3/s)       date
# 585   40764   Aug  2011    9  13.718      23082.277263 2011-08-09
# 1970  42180   Jun  2015   25  13.678      65123.044579 2015-06-25
# 1971  42181   Jun  2015   26  13.002      33627.339507 2015-06-26
# 2000  42210   Jul  2015   25  12.422      18546.308724 2015-07-25
# 2001  42211   Jul  2015   26  13.518      55859.654485 2015-07-26
# 2002  42212   Jul  2015   27  13.164      39520.085185 2015-07-27
# 2007  42217   Aug  2015    1  13.062      35708.057028 2015-08-01
# 2026  42236   Aug  2015   20  12.928      31215.386624 2015-08-20
# 3447  43657   Jul  2019   11  12.972      17079.076841 2019-07-11
# 3450  43660   Jul  2019   14  13.278      21928.663187 2019-07-14

# %%
df.describe()
# Out:
#                Date         Year          Day        WL(m)  Discharge (m3/s)
# count   3621.000000  3621.000000  3621.000000  3621.000000       3621.000000
# mean   42003.731014  2014.495996    15.725490     7.041680        162.720583
# std     1058.829788     2.884096     8.799252     0.936005       2015.573411
# min    40179.000000  2010.000000     1.000000     5.912000          2.460066
# 25%    41084.000000  2012.000000     8.000000     6.530000          5.332894
# 50%    41990.000000  2014.000000    16.000000     6.790000          7.887603
# 75%    42925.000000  2017.000000    23.000000     7.294000         18.734552
# max    43830.000000  2019.000000    31.000000    13.718000      65123.044579

# %%
new_filt = discharge["Discharge (m3/s)"] <6000

# %%
filtered_discharge = discharge[new_filt]

# %%
fig, ax = plt.subplots(figsize=(12,5))
sns.boxplot(x = filtered_discharge["Month"],
                y = filtered_discharge['Discharge (m3/s)'], 
                ax = ax)
plt.savefig("lama_boxplot.jpg", dpi = 500)

# %%
df
# Out:
#        Date Month  Year  Day  WL(m)  Discharge (m3/s)       date
# 0     40179   Jan  2010    1   6.65          4.154046 2010-01-01
# 1     40180   Jan  2010    2   6.65          4.154046 2010-01-02
# 2     40181   Jan  2010    3   6.65          4.154046 2010-01-03
# 3     40182   Jan  2010    4   6.65          4.154046 2010-01-04
# 4     40183   Jan  2010    5   6.65          4.154046 2010-01-05
# ...     ...   ...   ...  ...    ...               ...        ...
# 3616  43826   Dec  2019   27   6.09          5.153798 2019-12-27
# 3617  43827   Dec  2019   28   6.09          5.153798 2019-12-28
# 3618  43828   Dec  2019   29   6.09          5.153798 2019-12-29
# 3619  43829   Dec  2019   30   6.08          5.063798 2019-12-30
# 3620  43830   Dec  2019   31   6.08          5.063798 2019-12-31
#
# [3621 rows x 7 columns]

# %%
filt = df["Discharge (m3/s)"] <6000

# %%
df_modified = df[filt]

# %%
df_modified
# Out:
#        Date Month  Year  Day  WL(m)  Discharge (m3/s)       date
# 0     40179   Jan  2010    1   6.65          4.154046 2010-01-01
# 1     40180   Jan  2010    2   6.65          4.154046 2010-01-02
# 2     40181   Jan  2010    3   6.65          4.154046 2010-01-03
# 3     40182   Jan  2010    4   6.65          4.154046 2010-01-04
# 4     40183   Jan  2010    5   6.65          4.154046 2010-01-05
# ...     ...   ...   ...  ...    ...               ...        ...
# 3616  43826   Dec  2019   27   6.09          5.153798 2019-12-27
# 3617  43827   Dec  2019   28   6.09          5.153798 2019-12-28
# 3618  43828   Dec  2019   29   6.09          5.153798 2019-12-29
# 3619  43829   Dec  2019   30   6.08          5.063798 2019-12-30
# 3620  43830   Dec  2019   31   6.08          5.063798 2019-12-31
#
# [3602 rows x 7 columns]

# %%
df_modified.to_excel("lama_discharge_modified.xlsx")
